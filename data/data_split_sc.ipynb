# %%
from sklearn.model_selection import KFold
import json

def k_fold_split(data, k):
    """
    Splits the given dataset into K folds.
    :param data: List or numpy array of data.
    :param k: Number of folds.
    :return: List of tuples containing (train_indices, test_indices) for each fold.
    """
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    folds = [(train_index, test_index) for train_index, test_index in kf.split(data)]
    
    return folds

def get_fold_data(data, indices):
    """
    Retrieves the actual data based on provided indices.
    :param data: List or numpy array of data.
    :param indices: List of indices to retrieve.
    :return: List of data points corresponding to the indices.
    """
    return [data[i] for i in indices]


def save_to_jsonl(data, filename):
    """
    Save a list of dictionaries to a JSONL file.

    :param data: List of dictionaries to save.
    :param filename: The file path to save the JSONL file.
    """
    if not isinstance(data, list) or not all(isinstance(item, dict) for item in data):
        raise ValueError("Data must be a list of dictionaries")

    with open(filename, 'w', encoding='utf-8') as f:
        for item in data:
            f.write(json.dumps(item, ensure_ascii=False) + '\n')

# %%
import jsonlines
file_name = "./scienceworld/test.jsonl"
data_list = []
with open(file_name, 'r+', encoding='utf-8') as f:
    for item in jsonlines.Reader(f):
        data_list.append(item)

folds = k_fold_split(data_list, k=4)
# Display the split indices and retrieve actual data
for i, (train, test) in enumerate(folds):
    print(f"Fold {i+1}\n")
    train_data = get_fold_data(data_list, train)
    test_data = get_fold_data(data_list, test)
    save_to_jsonl(train_data, filename="./scienceworld/train_data_%s.jsonl"%i)
    save_to_jsonl(test_data, filename="./scienceworld/test_data_%s.jsonl"%i)
    
    print('len(train_data)', len(train_data))
    count_dict = dict()
    for item in train_data:
        task_category = item["additional_info"]["env_name"]
        if task_category not in count_dict.keys():
            count_dict[task_category] = 1
        else:
            count_dict[task_category] += 1
    for item in count_dict:
        print(item, count_dict[item])
    print('-------------------')
    print('len(test_data)', len(test_data))
    count_dict = dict()
    for item in test_data:
        task_category = item["additional_info"]["env_name"]
        if task_category not in count_dict.keys():
            count_dict[task_category] = 1
        else:
            count_dict[task_category] += 1
    for item in count_dict:
        print(item, count_dict[item])
    print('===========================')
# Out:
# Fold 1
#
# len(train_data) 67
# lifespan-longest-lived 8
# lifespan-longest-lived-then-shortest-lived 6
# lifespan-shortest-lived 8
# measure-melting-point-known-substance 6
# measure-melting-point-unknown-substance 4
# use-thermometer 7
# identify-life-stages-1 4
# chemistry-mix-paint-tertiary-color 2
# find-animal 3
# find-living-thing 4
# find-non-living-thing 5
# boil 3
# change-the-state-of-matter-of 2
# chemistry-mix 3
# chemistry-mix-paint-secondary-color 2
# -------------------
# len(test_data) 23
# lifespan-longest-lived 1
# lifespan-longest-lived-then-shortest-lived 3
# measure-melting-point-known-substance 2
# measure-melting-point-unknown-substance 2
# freeze 1
# chemistry-mix-paint-tertiary-color 1
# find-animal 3
# find-living-thing 2
# boil 1
# change-the-state-of-matter-of 2
# chemistry-mix-paint-secondary-color 1
# use-thermometer 1
# lifespan-shortest-lived 1
# identify-life-stages-1 1
# find-non-living-thing 1
# ===========================
# Fold 2
#
# len(train_data) 67
# lifespan-longest-lived 8
# lifespan-longest-lived-then-shortest-lived 7
# lifespan-shortest-lived 7
# measure-melting-point-known-substance 6
# measure-melting-point-unknown-substance 5
# use-thermometer 6
# freeze 1
# identify-life-stages-1 2
# chemistry-mix-paint-tertiary-color 3
# find-animal 4
# find-living-thing 5
# find-non-living-thing 3
# boil 2
# change-the-state-of-matter-of 4
# chemistry-mix 2
# chemistry-mix-paint-secondary-color 2
# -------------------
# len(test_data) 23
# lifespan-longest-lived-then-shortest-lived 2
# lifespan-shortest-lived 2
# measure-melting-point-known-substance 2
# measure-melting-point-unknown-substance 1
# use-thermometer 2
# identify-life-stages-1 3
# find-animal 2
# find-living-thing 1
# find-non-living-thing 3
# boil 2
# chemistry-mix 1
# chemistry-mix-paint-secondary-color 1
# lifespan-longest-lived 1
# ===========================
# Fold 3
#
# len(train_data) 68
# lifespan-longest-lived 8
# lifespan-longest-lived-then-shortest-lived 6
# lifespan-shortest-lived 6
# measure-melting-point-known-substance 6
# measure-melting-point-unknown-substance 5
# use-thermometer 3
# freeze 1
# identify-life-stages-1 5
# chemistry-mix-paint-tertiary-color 3
# find-animal 5
# find-living-thing 5
# find-non-living-thing 6
# boil 3
# change-the-state-of-matter-of 3
# chemistry-mix 1
# chemistry-mix-paint-secondary-color 2
# -------------------
# len(test_data) 22
# lifespan-longest-lived-then-shortest-lived 3
# lifespan-shortest-lived 3
# use-thermometer 5
# find-animal 1
# boil 1
# change-the-state-of-matter-of 1
# chemistry-mix 2
# chemistry-mix-paint-secondary-color 1
# lifespan-longest-lived 1
# measure-melting-point-known-substance 2
# measure-melting-point-unknown-substance 1
# find-living-thing 1
# ===========================
# Fold 4
#
# len(train_data) 68
# lifespan-longest-lived 3
# lifespan-longest-lived-then-shortest-lived 8
# lifespan-shortest-lived 6
# measure-melting-point-known-substance 6
# measure-melting-point-unknown-substance 4
# use-thermometer 8
# freeze 1
# identify-life-stages-1 4
# chemistry-mix-paint-tertiary-color 1
# find-animal 6
# find-living-thing 4
# find-non-living-thing 4
# boil 4
# change-the-state-of-matter-of 3
# chemistry-mix 3
# chemistry-mix-paint-secondary-color 3
# -------------------
# len(test_data) 22
# lifespan-longest-lived 6
# measure-melting-point-unknown-substance 2
# identify-life-stages-1 1
# chemistry-mix-paint-tertiary-color 2
# find-living-thing 2
# find-non-living-thing 2
# change-the-state-of-matter-of 1
# lifespan-shortest-lived 3
# measure-melting-point-known-substance 2
# lifespan-longest-lived-then-shortest-lived 1
# ===========================
