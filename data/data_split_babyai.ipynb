# %%
from sklearn.model_selection import KFold
import json

def k_fold_split(data, k):
    """
    Splits the given dataset into K folds.
    :param data: List or numpy array of data.
    :param k: Number of folds.
    :return: List of tuples containing (train_indices, test_indices) for each fold.
    """
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    folds = [(train_index, test_index) for train_index, test_index in kf.split(data)]
    
    return folds

def get_fold_data(data, indices):
    """
    Retrieves the actual data based on provided indices.
    :param data: List or numpy array of data.
    :param indices: List of indices to retrieve.
    :return: List of data points corresponding to the indices.
    """
    return [data[i] for i in indices]


def save_to_jsonl(data, filename):
    """
    Save a list of dictionaries to a JSONL file.

    :param data: List of dictionaries to save.
    :param filename: The file path to save the JSONL file.
    """
    if not isinstance(data, list) or not all(isinstance(item, dict) for item in data):
        raise ValueError("Data must be a list of dictionaries")

    with open(filename, 'w', encoding='utf-8') as f:
        for item in data:
            f.write(json.dumps(item, ensure_ascii=False) + '\n')

# %%
import jsonlines
file_name = "./babyai/test.jsonl"
data_list = []
with open(file_name, 'r+', encoding='utf-8') as f:
    for item in jsonlines.Reader(f):
        data_list.append(item)

folds = k_fold_split(data_list, k=4)
# Display the split indices and retrieve actual data
for i, (train, test) in enumerate(folds):
    print(f"Fold {i+1}\n")
    train_data = get_fold_data(data_list, train)
    test_data = get_fold_data(data_list, test)
    save_to_jsonl(train_data, filename="./babyai/train_data_%s.jsonl"%i)
    save_to_jsonl(test_data, filename="./babyai/test_data_%s.jsonl"%i)
    
    print('len(train_data)', len(train_data))
    count_dict = dict()
    for item in train_data:
        task_category = item["additional_info"]["subtask"]
        if task_category not in count_dict.keys():
            count_dict[task_category] = 1
        else:
            count_dict[task_category] += 1
    for item in count_dict:
        print(item, count_dict[item])
    print('-------------------')
    print('len(test_data)', len(test_data))
    count_dict = dict()
    for item in test_data:
        task_category = item["additional_info"]["subtask"]
        if task_category not in count_dict.keys():
            count_dict[task_category] = 1
        else:
            count_dict[task_category] += 1
    for item in count_dict:
        print(item, count_dict[item])
    print('===========================')
# Out:
# Fold 1
#
# len(train_data) 84
# BabyAI-GoToRedBallGrey-v0 3
# BabyAI-GoToRedBall-v0 3
# BabyAI-GoToRedBallNoDists-v0 2
# BabyAI-GoToObjS6-v0 3
# BabyAI-GoToLocalS8N7-v0 3
# BabyAI-GoToObjMazeS7-v0 3
# BabyAI-GoToImpUnlock-v0 3
# BabyAI-GoToSeqS5R2-v0 3
# BabyAI-GoToRedBlueBall-v0 4
# BabyAI-GoToDoor-v0 3
# BabyAI-GoToObjDoor-v0 2
# BabyAI-Open-v0 2
# BabyAI-OpenRedDoor-v0 4
# BabyAI-OpenDoorLoc-v0 2
# BabyAI-OpenRedBlueDoorsDebug-v0 4
# BabyAI-OpenDoorsOrderN4Debug-v0 3
# BabyAI-Pickup-v0 2
# BabyAI-UnblockPickup-v0 2
# BabyAI-PickupLoc-v0 3
# BabyAI-PickupDistDebug-v0 4
# BabyAI-PickupAbove-v0 3
# BabyAI-Unlock-v0 3
# BabyAI-UnlockLocalDist-v0 2
# BabyAI-UnlockPickupDist-v0 4
# BabyAI-BlockedUnlockPickup-v0 3
# BabyAI-UnlockToUnlock-v0 3
# BabyAI-FindObjS7-v0 4
# BabyAI-KeyCorridorS6R3-v0 4
# -------------------
# len(test_data) 28
# BabyAI-GoToRedBallGrey-v0 1
# BabyAI-GoToRedBall-v0 1
# BabyAI-GoToRedBallNoDists-v0 2
# BabyAI-GoToObjS6-v0 1
# BabyAI-GoToLocalS8N7-v0 1
# BabyAI-GoToObjMazeS7-v0 1
# BabyAI-GoToImpUnlock-v0 1
# BabyAI-GoToSeqS5R2-v0 1
# BabyAI-GoToDoor-v0 1
# BabyAI-GoToObjDoor-v0 2
# BabyAI-Open-v0 2
# BabyAI-OpenDoorLoc-v0 2
# BabyAI-OpenDoorsOrderN4Debug-v0 1
# BabyAI-Pickup-v0 2
# BabyAI-UnblockPickup-v0 2
# BabyAI-PickupLoc-v0 1
# BabyAI-PickupAbove-v0 1
# BabyAI-Unlock-v0 1
# BabyAI-UnlockLocalDist-v0 2
# BabyAI-BlockedUnlockPickup-v0 1
# BabyAI-UnlockToUnlock-v0 1
# ===========================
# Fold 2
#
# len(train_data) 84
# BabyAI-GoToRedBallGrey-v0 4
# BabyAI-GoToRedBall-v0 2
# BabyAI-GoToRedBallNoDists-v0 3
# BabyAI-GoToObjS6-v0 3
# BabyAI-GoToLocalS8N7-v0 2
# BabyAI-GoToObjMazeS7-v0 4
# BabyAI-GoToImpUnlock-v0 3
# BabyAI-GoToSeqS5R2-v0 2
# BabyAI-GoToRedBlueBall-v0 1
# BabyAI-GoToDoor-v0 3
# BabyAI-GoToObjDoor-v0 3
# BabyAI-Open-v0 3
# BabyAI-OpenRedDoor-v0 4
# BabyAI-OpenDoorLoc-v0 4
# BabyAI-OpenRedBlueDoorsDebug-v0 3
# BabyAI-OpenDoorsOrderN4Debug-v0 4
# BabyAI-Pickup-v0 2
# BabyAI-UnblockPickup-v0 3
# BabyAI-PickupLoc-v0 4
# BabyAI-PickupDistDebug-v0 2
# BabyAI-PickupAbove-v0 3
# BabyAI-Unlock-v0 4
# BabyAI-UnlockLocalDist-v0 3
# BabyAI-UnlockPickupDist-v0 3
# BabyAI-BlockedUnlockPickup-v0 3
# BabyAI-UnlockToUnlock-v0 4
# BabyAI-FindObjS7-v0 2
# BabyAI-KeyCorridorS6R3-v0 3
# -------------------
# len(test_data) 28
# BabyAI-GoToRedBall-v0 2
# BabyAI-GoToRedBallNoDists-v0 1
# BabyAI-GoToObjS6-v0 1
# BabyAI-GoToLocalS8N7-v0 2
# BabyAI-GoToImpUnlock-v0 1
# BabyAI-GoToSeqS5R2-v0 2
# BabyAI-GoToRedBlueBall-v0 3
# BabyAI-GoToDoor-v0 1
# BabyAI-GoToObjDoor-v0 1
# BabyAI-Open-v0 1
# BabyAI-OpenRedBlueDoorsDebug-v0 1
# BabyAI-Pickup-v0 2
# BabyAI-UnblockPickup-v0 1
# BabyAI-PickupDistDebug-v0 2
# BabyAI-PickupAbove-v0 1
# BabyAI-UnlockLocalDist-v0 1
# BabyAI-UnlockPickupDist-v0 1
# BabyAI-BlockedUnlockPickup-v0 1
# BabyAI-FindObjS7-v0 2
# BabyAI-KeyCorridorS6R3-v0 1
# ===========================
# Fold 3
#
# len(train_data) 84
# BabyAI-GoToRedBallGrey-v0 3
# BabyAI-GoToRedBall-v0 3
# BabyAI-GoToRedBallNoDists-v0 3
# BabyAI-GoToObjS6-v0 3
# BabyAI-GoToLocalS8N7-v0 3
# BabyAI-GoToObjMazeS7-v0 4
# BabyAI-GoToImpUnlock-v0 2
# BabyAI-GoToSeqS5R2-v0 4
# BabyAI-GoToRedBlueBall-v0 4
# BabyAI-GoToDoor-v0 3
# BabyAI-GoToObjDoor-v0 3
# BabyAI-Open-v0 3
# BabyAI-OpenRedDoor-v0 1
# BabyAI-OpenDoorLoc-v0 3
# BabyAI-OpenRedBlueDoorsDebug-v0 2
# BabyAI-OpenDoorsOrderN4Debug-v0 3
# BabyAI-Pickup-v0 4
# BabyAI-UnblockPickup-v0 4
# BabyAI-PickupLoc-v0 3
# BabyAI-PickupDistDebug-v0 2
# BabyAI-PickupAbove-v0 3
# BabyAI-Unlock-v0 3
# BabyAI-UnlockLocalDist-v0 3
# BabyAI-UnlockPickupDist-v0 3
# BabyAI-BlockedUnlockPickup-v0 3
# BabyAI-UnlockToUnlock-v0 3
# BabyAI-FindObjS7-v0 4
# BabyAI-KeyCorridorS6R3-v0 2
# -------------------
# len(test_data) 28
# BabyAI-GoToRedBallGrey-v0 1
# BabyAI-GoToRedBall-v0 1
# BabyAI-GoToRedBallNoDists-v0 1
# BabyAI-GoToObjS6-v0 1
# BabyAI-GoToLocalS8N7-v0 1
# BabyAI-GoToImpUnlock-v0 2
# BabyAI-GoToDoor-v0 1
# BabyAI-GoToObjDoor-v0 1
# BabyAI-Open-v0 1
# BabyAI-OpenRedDoor-v0 3
# BabyAI-OpenDoorLoc-v0 1
# BabyAI-OpenRedBlueDoorsDebug-v0 2
# BabyAI-OpenDoorsOrderN4Debug-v0 1
# BabyAI-PickupLoc-v0 1
# BabyAI-PickupDistDebug-v0 2
# BabyAI-PickupAbove-v0 1
# BabyAI-Unlock-v0 1
# BabyAI-UnlockLocalDist-v0 1
# BabyAI-UnlockPickupDist-v0 1
# BabyAI-BlockedUnlockPickup-v0 1
# BabyAI-UnlockToUnlock-v0 1
# BabyAI-KeyCorridorS6R3-v0 2
# ===========================
# Fold 4
#
# len(train_data) 84
# BabyAI-GoToRedBallGrey-v0 2
# BabyAI-GoToRedBall-v0 4
# BabyAI-GoToRedBallNoDists-v0 4
# BabyAI-GoToObjS6-v0 3
# BabyAI-GoToLocalS8N7-v0 4
# BabyAI-GoToObjMazeS7-v0 1
# BabyAI-GoToImpUnlock-v0 4
# BabyAI-GoToSeqS5R2-v0 3
# BabyAI-GoToRedBlueBall-v0 3
# BabyAI-GoToDoor-v0 3
# BabyAI-GoToObjDoor-v0 4
# BabyAI-Open-v0 4
# BabyAI-OpenRedDoor-v0 3
# BabyAI-OpenDoorLoc-v0 3
# BabyAI-OpenRedBlueDoorsDebug-v0 3
# BabyAI-OpenDoorsOrderN4Debug-v0 2
# BabyAI-Pickup-v0 4
# BabyAI-UnblockPickup-v0 3
# BabyAI-PickupLoc-v0 2
# BabyAI-PickupDistDebug-v0 4
# BabyAI-PickupAbove-v0 3
# BabyAI-Unlock-v0 2
# BabyAI-UnlockLocalDist-v0 4
# BabyAI-UnlockPickupDist-v0 2
# BabyAI-BlockedUnlockPickup-v0 3
# BabyAI-UnlockToUnlock-v0 2
# BabyAI-FindObjS7-v0 2
# BabyAI-KeyCorridorS6R3-v0 3
# -------------------
# len(test_data) 28
# BabyAI-GoToRedBallGrey-v0 2
# BabyAI-GoToObjS6-v0 1
# BabyAI-GoToObjMazeS7-v0 3
# BabyAI-GoToSeqS5R2-v0 1
# BabyAI-GoToRedBlueBall-v0 1
# BabyAI-GoToDoor-v0 1
# BabyAI-OpenRedDoor-v0 1
# BabyAI-OpenDoorLoc-v0 1
# BabyAI-OpenRedBlueDoorsDebug-v0 1
# BabyAI-OpenDoorsOrderN4Debug-v0 2
# BabyAI-UnblockPickup-v0 1
# BabyAI-PickupLoc-v0 2
# BabyAI-PickupAbove-v0 1
# BabyAI-Unlock-v0 2
# BabyAI-UnlockPickupDist-v0 2
# BabyAI-BlockedUnlockPickup-v0 1
# BabyAI-UnlockToUnlock-v0 2
# BabyAI-FindObjS7-v0 2
# BabyAI-KeyCorridorS6R3-v0 1
# ===========================
